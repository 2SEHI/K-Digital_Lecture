# %% [markdown]
# ## 빅데이터 기반 AI 응용 솔루션 개발자 전문과정
#
# ### 교과목명 : 데이터 수집_전처리_분석용데이터셋_구축
# - 평가일 : 21. 8. 27
# - 성명 : 이세희

# %% [markdown]
# ## 1.seaborn 의 titanic 데이터를 호출해서 5개의 데이터를 출력하시오.

# %%
import pandas as pd
import seaborn as sbn
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %% [markdown]
# #### 답안

# %%
import pandas as pd
import seaborn as sbn

# seaborn의 데이터셋호출 함수 확인
dir(sbn)

# 타이타닉 데이터셋 호출
titanic = sbn.load_dataset('titanic')
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %% [markdown]
# ## 2.auto-mpg.csv 파일의 내용을 읽어서 5개의 데이터를 출력하시오.

# %%
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70       1                ford torino

# %% [markdown]
# #### 답안

# %%
import pandas as pd 
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/k-digital/과제/0827_데이터수집,DB/data/auto-mpg.csv')
df.head(5)
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70       1                ford torino

# %% [markdown]
# ## 3.mpg 데이터의 origin 열의 데이터를 category 타입으로 변경하시오.

# %%
# Out:
# int64
# category

# %% [markdown]
# #### 답안

# %%
print(df['origin'].dtype)
df['origin'] = pd.Series(df['origin'], dtype='category')
print(df['origin'].dtype)
# Out:
# int64
# category

# %%
print(df['origin'].dtype)
df['origin'] = df['origin'].astype('category')
print(df['origin'].dtype)
# Out:
# int64
# category

# %%
print(df['origin'].dtype)
df['origin'] = pd.Categorical(df['origin'])
print(df['origin'].dtype)
# Out:
# int64
# category

# %% [markdown]
# ## 4.mpg 데이터의 weight의 데이터를 정규화해서 출력하시오.
# sklearn 라이브러리의 processing 의 StandardScaler 를 이용하시오.

# %%
from sklearn import preprocessing
import numpy as np
x = df[['weight']].values

# %% [markdown]
# #### 답안

# %%
from sklearn import preprocessing
import numpy as np
import matplotlib.pyplot as plt
x = df[['weight']].values
plt.hist(x)
plt.title('original weight')
plt.show()

std = preprocessing.StandardScaler()
x_scaled = std.fit_transform(x)
plt.hist(x_scaled)
plt.title('scaled weight')
plt.show()

# %% [markdown]
# ## 5.아래 데이터를 가지고 2차 다항 특성을 적용한 데이털르 생성하시오.

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures

# 특성 행렬을 만듭니다.
features = np.array([[2, 3],
                     [1, 2],
                     [22, 6]])
# Out:
# array([[  2.,   3.,   4.,   6.,   9.],
#        [  1.,   2.,   1.,   2.,   4.],
#        [ 22.,   6., 484., 132.,  36.]])

# %% [markdown]
# #### 답안

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures

# 특성 행렬을 만듭니다.
features = np.array([[2, 3],
                     [1, 2],
                     [22, 6]])


p = PolynomialFeatures(degree=2, include_bias =False)
fit_data = p.fit_transform(features)
fit_data
# Out:
# array([[  2.,   3.,   4.,   6.,   9.],
#        [  1.,   2.,   1.,   2.,   4.],
#        [ 22.,   6., 484., 132.,  36.]])

# %% [markdown]
# ## 6.아래 데이터를 30을 기준으로 0 과 1로 이산화하시오.
# - 연속된 데이터를 이산화

# %%
import numpy as np

# 특성을 만듭니다.
age = np.array([[13],
                [30],
                [67],
                [36],
                [64],
                [24]])
# Out:
# [[0]
#  [1]
#  [1]
#  [1]
#  [1]
#  [0]]

# %% [markdown]
# #### 답안

# %%
import numpy as np

# 특성을 만듭니다.
age = np.array([[13],
                [30],
                [67],
                [36],
                [64],
                [24]])
binary_age = np.where(age < 30, 0, 1)
binary_age
# Out:
# array([[0],
#        [1],
#        [1],
#        [1],
#        [1],
#        [0]])

# %% [markdown]
# ## 7.타이타닉 데이터에서 NaN 값이 500개 이상인 컬럼을 제거하시오.

# %%
#NaN 값이 500개 이상인 컬럼 제거
df_thresh = ?

print(df_thresh.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %% [markdown]
# #### 답안

# %%
#NaN 값이 500개 이상인 컬럼 제거
# titanic의 데이터 정보확인
print(titanic.info())

# dropna의 thresh를 이용하여 NaN값이 500개 이상인 컬럼을 제거
df_thresh = titanic.dropna(thresh=500,axis=1)
# titanic의 데이터 정보확인
print(df_thresh.info())
print(df_thresh.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# ## 8.타이타닉 데이터에서 age 열의 값이 NaN인 행 삭제

# %%
df_age = ?
print(df_age.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     714 non-null    int64
#  1   pclass       714 non-null    int64
#  2   sex          714 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        714 non-null    int64
#  5   parch        714 non-null    int64
#  6   fare         714 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        714 non-null    category
#  9   who          714 non-null    object
#  10  adult_male   714 non-null    bool
#  11  embark_town  712 non-null    object
#  12  alive        714 non-null    object
#  13  alone        714 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 69.2+ KB
# None

# %% [markdown]
# #### 답안

# %%
df_age = df_thresh.dropna(axis=0, how='any', subset=['age'])
df_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     714 non-null    int64
#  1   pclass       714 non-null    int64
#  2   sex          714 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        714 non-null    int64
#  5   parch        714 non-null    int64
#  6   fare         714 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        714 non-null    category
#  9   who          714 non-null    object
#  10  adult_male   714 non-null    bool
#  11  embark_town  712 non-null    object
#  12  alive        714 non-null    object
#  13  alone        714 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 69.1+ KB

# %% [markdown]
# ## 9.결측치를 처리한 데이터를 가지고 age를 3개로 분할해서 원핫인코딩을 수행하시오.

# %%
bin_names = ['소년', '청년', '노년']
# Out:
#     소년  청년  노년
# 0    1   0   0
# 1    0   1   0
# 2    1   0   0
# 3    0   1   0
# 4    0   1   0
# 6    0   0   1
# 7    1   0   0
# 8    0   1   0
# 9    1   0   0
# 10   1   0   0
# /var/folders/42/fxl3_n31121f16yj69fbrb_m0000gn/T/ipykernel_19611/1481031345.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_age['age_bin'] = pd.cut(x=df_age['age'],     # 데이터 배열

# %% [markdown]
# #### 답안

# %%
bin_names = ['소년', '청년', '노년']
df_age['age_bin'] = pd.cut(x=df_age['age'],bins=3,labels=bin_names, ordered=False)
pd.get_dummies(df_age['age_bin'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      소년  청년  노년
# 0     1   0   0
# 1     0   1   0
# 2     1   0   0
# 3     0   1   0
# 4     0   1   0
# ..   ..  ..  ..
# 885   0   1   0
# 886   0   1   0
# 887   1   0   0
# 889   1   0   0
# 890   0   1   0
#
# [714 rows x 3 columns]

# %% [markdown]
# ## 10.titanic 데이터를 8:2 의 비율로 데이터를 분할하시오.

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = ?
print(train_set.shape)
print(test_set.shape)
# Out:
# (712, 15)
# (179, 15)

# %% [markdown]
# #### 답안

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(titanic, test_size=0.2)
print(train_set.shape)
print(test_set.shape)
# Out:
# (712, 15)
# (179, 15)
